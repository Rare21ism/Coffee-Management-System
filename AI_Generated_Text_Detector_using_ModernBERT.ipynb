# %% [markdown]
# # Step 1: Install Dependencies

# %%
# Install necessary libraries for text classification and deployment
# !pip install -q transformers datasets gradio

# %% [markdown]
# # Step 2: Load & Prepare Dataset

# %%
from datasets import Dataset

# Define AI-generated text samples (from ChatGPT, DeepSeek, Claude, etc.)
ai_text_samples = [
    "Artificial intelligence is revolutionizing industries by automating processes.",
    "The universe is vast, with countless galaxies and undiscovered planets.",
    "Quantum computing has the potential to solve complex problems exponentially faster.",
    "AI-generated text can sometimes mimic human writing patterns convincingly."
    "Artificial intelligence has revolutionized multiple industries by enhancing efficiency and reducing human error.",
"The growing demand for automation has led to significant advancements in machine learning algorithms.",
"In today’s digital age, data is considered one of the most valuable resources available to organizations.",
"Climate change remains one of the most pressing global challenges requiring immediate collective action.",
"The integration of technology in education has transformed traditional learning methodologies.",
"Machine learning models rely heavily on the quality and quantity of training data to achieve accurate predictions.",
"The evolution of artificial intelligence has created both opportunities and ethical dilemmas.",
"Healthcare systems are increasingly adopting AI tools to improve diagnostics and patient care.",
"The implementation of renewable energy sources is crucial for achieving sustainable development goals.",
"Social media platforms play a significant role in shaping public opinion and consumer behavior.",
"Blockchain technology offers a decentralized approach to secure and transparent data transactions.",
"Virtual reality and augmented reality are redefining the way people interact with digital environments.",
"The success of deep learning depends on high computational power and optimized neural network architectures.",
"The pandemic accelerated the global shift toward remote work and digital collaboration tools.",
"Cybersecurity threats continue to evolve as technology becomes more interconnected and complex.",
"The study highlights the correlation between technological innovation and economic growth.",
"AI-driven analytics are helping businesses make more informed and data-backed decisions.",
"The expansion of the Internet of Things has created a vast network of connected devices and sensors.",
"Ethical considerations must be addressed when developing and deploying autonomous systems.",
"Data privacy regulations have become more stringent to protect user information in digital spaces.",
"The convergence of big data and artificial intelligence enables predictive insights across industries.",
"Digital transformation has become a strategic priority for organizations seeking long-term competitiveness.",
"Natural language processing allows machines to interpret and generate human-like text.",
"AI-based recommendation systems personalize user experiences on streaming and shopping platforms.",
"The automation of routine tasks is reshaping the nature of employment across various sectors.",
"The continuous evolution of AI requires a multidisciplinary approach to research and development.",
"Technological innovation is driving unprecedented changes in communication and information exchange.",
"Smart cities leverage data-driven solutions to improve infrastructure and quality of life.",
"Cloud computing provides scalable storage and processing capabilities for businesses of all sizes.",
"The combination of robotics and artificial intelligence is transforming manufacturing industries.",
"Data visualization tools help simplify complex datasets into understandable graphical representations.",
"Predictive analytics can forecast future trends based on historical data patterns.",
"AI-powered chatbots enhance customer service by providing instant and automated responses.",
"The use of drones has expanded from photography to agriculture, logistics, and surveillance.",
"Facial recognition systems are becoming increasingly prevalent in both security and commercial applications.",
"The rise of automation necessitates reskilling and upskilling the global workforce.",
"Data scientists play a crucial role in extracting actionable insights from raw information.",
"Ethical AI development focuses on transparency, accountability, and fairness in algorithms.",
"The financial industry benefits from AI through fraud detection and risk assessment models.",
"Virtual assistants utilize speech recognition to perform tasks based on user commands.",
"The growth of e-commerce platforms has been driven by advances in payment systems and logistics.",
"Reinforcement learning enables agents to learn optimal strategies through trial and error.",
"The accuracy of AI predictions depends largely on data preprocessing and feature engineering.",
"AI-generated content is increasingly used in marketing, journalism, and entertainment sectors.",
"Smart healthcare devices monitor patient vitals and transmit real-time health data to doctors.",
"Digital twins simulate real-world systems to optimize performance and predict maintenance needs.",
"AI ethics debates often center around bias, privacy, and accountability concerns.",
"The metaverse concept envisions a shared virtual space integrating augmented and virtual realities.",
"Computer vision enables machines to interpret and process visual information from images or videos.",
"AI adoption in agriculture improves crop monitoring, yield prediction, and resource management.",
"The efficiency of recommendation algorithms influences user engagement on digital platforms.",
"The automation of document processing reduces human workload and improves data accuracy.",
"Deep reinforcement learning has achieved remarkable success in gaming and robotics applications.",
"AI applications in finance are improving portfolio management and algorithmic trading strategies.",
"The future of work will likely involve collaboration between humans and intelligent machines.",
"AI-powered translation systems are breaking down language barriers in global communication.",
"The continuous learning capability of neural networks allows systems to adapt over time.",
"Data preprocessing techniques such as normalization and encoding are essential for model training.",
"The ethical implications of AI surveillance systems are a growing concern among policymakers.",
"AI systems require extensive datasets to generalize effectively across diverse scenarios.",
"The development of autonomous vehicles depends heavily on real-time perception and decision-making models.",
"AI tools assist researchers in analyzing massive scientific datasets with greater precision.",
"Hybrid models combining symbolic and neural approaches are gaining attention in AI research.",
"The expansion of 5G networks enhances data transmission speed and supports IoT applications.",
"AI-driven diagnostics are helping detect diseases earlier and improve treatment outcomes.",
"The future of AI will depend on balancing innovation with ethical responsibility.",
"Smart home devices use AI to learn user preferences and automate daily routines.",
"The use of AI in education allows for personalized learning experiences tailored to individual needs.",
"Generative AI can produce text, images, and music that closely resemble human creativity.",
"The environmental impact of large-scale AI training models is becoming a key research topic.",
"AI governance frameworks aim to ensure responsible innovation and societal benefit.",
"The performance of deep neural networks improves with increased data and computational resources.",
"AI algorithms are now capable of outperforming humans in specific cognitive tasks.",
"The intersection of neuroscience and AI may lead to more biologically inspired machine intelligence.",
"AI tools are enabling more efficient decision-making in supply chain and logistics operations.",
"The rise of explainable AI emphasizes transparency in model outputs and reasoning.",
"AI-based forecasting models help predict market trends and economic shifts.",
"Digital assistants are increasingly integrated into smartphones, cars, and home appliances.",
"The scalability of AI solutions depends on cloud infrastructure and distributed computing.",
"The collaboration between academia and industry accelerates advancements in artificial intelligence.",
"The use of AI in entertainment has led to more realistic animations and character designs.",
"Edge computing allows AI models to operate locally on devices without constant cloud connectivity.",
"The role of AI in climate modeling helps improve predictions of environmental changes.",
"AI-based emotion recognition systems analyze facial expressions and vocal tones.",
"Reinforcement learning techniques have been applied to optimize robotic control systems.",
"The potential of AI in legal analytics is transforming how law firms process case data.",
"The democratization of AI tools allows startups to compete with larger organizations.",
"The quality of AI-generated text continues to improve with advancements in transformer models.",
"The integration of AI in cybersecurity enhances real-time threat detection and response.",
"AI-powered creativity tools assist artists, writers, and designers in generating new ideas.",
"The alignment problem in AI research focuses on ensuring systems act in accordance with human values.",
"The expansion of AI applications across domains highlights its transformative potential.",
"The combination of AI and quantum computing could redefine the limits of computational power.",
"The increasing sophistication of AI models raises important questions about data ethics.",
"Automated image captioning demonstrates the ability of AI to connect vision and language understanding.",
"Human-in-the-loop systems ensure that AI decisions remain guided by human judgment and oversight.",
"The acceleration of AI innovation depends on open-source collaboration and shared research efforts.",
"AI’s role in modern society continues to expand, influencing nearly every aspect of human life.",
"Responsible AI adoption requires careful regulation, education, and interdisciplinary collaboration."
]

# Define human-written text samples (from Wikipedia, books, articles)
human_text_samples = [
    "In the spring of 1945, as the war in Europe was drawing to a close, the Allied forces were making significant advances.",
    "To bake a perfect loaf of bread, you need to carefully measure the ingredients and allow for proper rising time.",
    "The novel's protagonist faced a moral dilemma that forced her to question her deepest beliefs.",
    "Exploring the ancient ruins, we marveled at the engineering prowess of civilizations long past.",
    "The journalist's investigative report uncovered a complex web of corruption within the local government.",
    "Learning a new language opens up opportunities to connect with people from different cultures.",
    "The artist's use of color and light created a captivating and emotionally resonant painting.",
    "Hiking in the mountains provided a breathtaking view and a sense of peace and tranquility.",
    "The scientific paper presented groundbreaking research on the potential of renewable energy sources.",
    "Reading classic literature can provide insights into the human condition and timeless themes.",
    "When I first moved to the city, the noise felt overwhelming, but now it feels like a heartbeat I can’t live without.",
    "The smell of freshly brewed coffee reminded me of my grandmother’s kitchen on lazy Sunday mornings.",
    "Every summer, we used to visit the lake house and spend hours swimming until the sun went down.",
    "The old photograph had faded over time, but the memories it captured remained vivid.",
    "She paused before replying, knowing that her words could change the course of the conversation.",
    "The marketplace buzzed with life, filled with vibrant colors and the scent of spices in the air.",
    "The teacher’s patience made even the most difficult subjects seem approachable.",
    "Rain tapped softly against the window, creating a rhythm that matched my thoughts.",
    "When the curtain rose, the audience fell silent in anticipation of the first note.",
    "The journey through the desert tested not just our endurance, but our understanding of silence.",
    "I never realized how much I missed home until I smelled the ocean again.",
    "The dog wagged its tail excitedly every time it saw its owner return from work.",
    "She folded the letter neatly and placed it in a box filled with memories she couldn’t throw away.",
    "Each brushstroke on the canvas told a story of emotion that words could never fully express.",
    "We stayed up late that night, watching the stars until the horizon began to glow.",
    "The clock struck midnight, and the city seemed to hold its breath for a moment.",
    "He struggled to find the right words, afraid that honesty might cost him a friend.",
    "Autumn leaves crunched beneath our feet as we walked through the park.",
    "The aroma of freshly baked bread drifted from the small bakery at the corner of the street.",
    "She laughed, the kind of laughter that filled the room with warmth and light.",
    "The bookshop was quiet except for the soft sound of pages turning.",
    "Traveling alone taught me more about independence than any lesson ever could.",
    "The sound of the violin echoed through the hall, carrying both sorrow and beauty.",
    "He adjusted his tie nervously before stepping onto the stage.",
    "The train ride through the countryside was long, but the changing scenery made it worth it.",
    "She had a way of making ordinary moments feel extraordinary.",
    "I can still remember the smell of rain-soaked earth from that evening.",
    "We didn’t need words; the silence between us was enough.",
    "The old man’s stories seemed to come alive as the firelight danced across his face.",
    "Every ending, she believed, was just a different kind of beginning.",
    "The library became my favorite refuge during those long winter afternoons.",
    "The waves crashed against the rocks, echoing the turmoil inside my heart.",
    "When I found the letter, it felt like hearing a voice from the past.",
    "The festival lights shimmered in the night like stars brought down to Earth.",
    "She carried herself with quiet confidence, never needing to prove her worth.",
    "I watched the city lights flicker through the rain, each drop blurring the reflection.",
    "The first snowfall of the year always made the town look like a fairytale.",
    "He smiled the way people do when they remember something worth holding on to.",
    "The aroma of spices filled the kitchen, reminding me of family dinners from my childhood.",
    "We walked along the pier, our footsteps echoing softly against the wooden boards.",
    "Her handwriting, though imperfect, carried more emotion than any printed word.",
    "The garden was overgrown, but somehow, the wildness made it more beautiful.",
    "It was in that moment of silence that I realized how much had changed.",
    "The sea breeze carried a hint of salt and freedom.",
    "He had the look of someone who had seen too much and said too little.",
    "The candlelight flickered as the storm raged outside.",
    "Sometimes, the hardest goodbyes are the ones you never get to say.",
    "She found comfort in the familiar rhythm of her morning tea ritual.",
    "I watched as the sunrise painted the sky in shades of gold and pink.",
    "The photograph captured more than an image; it preserved a feeling.",
    "Every family gathering seemed to end with laughter and stories that never got old.",
    "The quiet after the storm was almost sacred.",
    "He picked up the guitar, and the first chord seemed to breathe life into the room.",
    "Walking through the museum felt like traveling through time.",
    "She spoke softly, but her words carried the weight of truth.",
    "The distant sound of church bells reminded me of home.",
    "He wrote her name in the sand, knowing the tide would soon wash it away.",
    "The café smelled of roasted beans and whispered conversations.",
    "Every scar, she said, tells a story worth remembering.",
    "We sat by the fire, sharing memories that felt like they belonged to another lifetime.",
    "The city skyline glittered like a thousand promises waiting to be kept.",
    "He lingered for a moment, as if time would allow him to stay a little longer.",
    "The child’s laughter echoed through the park, pure and unfiltered.",
    "She held the old photograph close, as if it could bring the past back to life.",
    "The concert ended, but the melody stayed with me long after.",
    "When the lights went out, the stars seemed brighter than ever.",
    "Every goodbye carried a little piece of hope for another hello.",
    "The silence between them spoke volumes about what was left unsaid.",
    "The field was golden with sunlight, and the air smelled faintly of wildflowers.",
    "He promised he’d write, but life, as always, had other plans.",
    "There was something both comforting and sad about familiar places.",
    "The painting in the gallery seemed to follow me with its gaze.",
    "I found an old notebook filled with dreams I’d forgotten I had.",
    "The laughter of children mixed with the distant hum of city life.",
    "She believed that kindness was the most beautiful form of strength.",
    "The sound of rain against the roof became my favorite lullaby.",
    "He reached for her hand, and in that gesture, forgiveness was given.",
    "The mountain trail tested our endurance but rewarded us with peace.",
    "As the pages turned, the story felt more like a memory than fiction.",
    "The marketplace smelled of fresh fruit and the sea breeze drifting from the harbor.",
    "We watched the fireworks fade into smoke, knowing the night was ending.",
    "Her voice trembled, but the truth she spoke was unshakable.",
    "The old clock in the hallway chimed, marking another hour gone by.",
    "The scent of jasmine filled the evening air as twilight settled in.",
    "He closed his eyes, letting the music carry him somewhere far away.",
    "The letter arrived late, but its message was right on time.",
    "Every journey begins with a single step, but courage keeps it going.",
    "The streetlights flickered, casting long shadows across the cobblestones.",
    "She smiled through her tears, understanding that endings can also be beautiful.",
    "The horizon burned orange as the sun dipped below the edge of the world.",
    "He stood by the river, tossing stones into the current, watching them disappear."
]

# Create labels for classification (1 = AI-generated, 0 = Human-written)
labels = [1] * len(ai_text_samples) + [0] * len(human_text_samples)

# Convert data into a Hugging Face Dataset format
dataset = Dataset.from_dict({"text": ai_text_samples + human_text_samples, "label": labels})

# Split dataset into training (80%) and testing (20%) sets
dataset = dataset.train_test_split(test_size=0.2)

# %% [markdown]
# # Step 3: Load & Tokenize `ModernBERT-base`

# %%
from transformers import AutoTokenizer

# ModernBERT model
model_name = "answerdotai/ModernBERT-base"

# Load ModernBERT tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Tokenize dataset with padding and truncation
tokenized_datasets = dataset.map(lambda x: tokenizer(x["text"],
                                                     padding="max_length",
                                                     truncation=True,
                                                     max_length=128), batched=True)
# Out:
# ...
# Map:   0%|          | 0/41 [00:00<?, ? examples/s]

# %% [markdown]
# # Step 4: Fine-Tune `ModernBERT-base`

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

# Load ModernBERT model for binary classification (2 labels: AI vs. Human)
model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels=2)

# Define training parameters
training_args = TrainingArguments(
    output_dir="./ai_detector",  # Directory to save model checkpoints
    learning_rate=0.001,  # Optimal learning rate for fine-tuning
    weight_decay=0.01,  # Regularization to prevent overfitting
    per_device_train_batch_size=5,  # Batch size for training
    per_device_eval_batch_size=5,  # Batch size for evaluation
    num_train_epochs=5,  # Number of training iterations over dataset
    eval_strategy="epoch",  # Evaluate model at the end of each epoch
    save_strategy="epoch",  # Save model at the end of each epoch
    logging_strategy="epoch",  # Log training/evaluation loss at each epoch
    logging_steps=1,  # Log training loss every step (for debugging)
    logging_dir="./logs",  # Directory to store training logs
    load_best_model_at_end=True,  # Load best model checkpoint after training
    report_to=["wandb"],  # Log training results to Weights & Biases
    # push_to_hub=True,  # Uncomment to upload model to Hugging Face Hub
)

# Initialize Trainer for model fine-tuning
trainer = Trainer(
    model=model,  # ModernBERT model
    args=training_args,  # Training configuration
    train_dataset=tokenized_datasets["train"],  # Training data
    eval_dataset=tokenized_datasets["test"],  # Evaluation data
    processing_class=tokenizer  # Tokenizer for processing text
)

# Start training the model
trainer.train()
# Out:
# Some weights of ModernBertForSequenceClassification were not initialized from the model checkpoint at answerdotai/ModernBERT-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': None, 'bos_token_id': None}.
#     <div>
#
#       <progress value='165' max='165' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [165/165 04:21, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
# ...

# %% [markdown]
# # Step 5: Test the Model

# %%
import numpy as np
from transformers import pipeline

# Load trained model as a text classifier pipeline
classifier = pipeline("text-classification", model=model, tokenizer=tokenizer)

# Example AI-generated text for testing
test_text = "Deep learning is a subset of machine learning that uses artificial neural networks to model and solve complex problems. It is characterized by deep architectures with multiple layers of interconnected neurons, allowing it to automatically learn hierarchical representations from data."

# Run text classification
result = classifier(test_text)

# Convert output label to human-readable format
label = "AI-Generated" if result[0]["label"] == "LABEL_1" else "Human-Written"
confidence = np.round(result[0]["score"], 3)

# Print classification result
print(f"Prediction: {label} (Confidence: {confidence})")
# Out:
# Device set to use cuda:0
# Prediction: AI-Generated (Confidence: 1.0)

# %% [markdown]
# # Step 6: Deploy as a Gradio Web App

# %%
import gradio as gr

# Define function for real-time AI text detection
def predict_ai_text(input_text):
    result = classifier(input_text)
    label = "AI-Generated" if result[0]["label"] == "LABEL_1" else "Human-Written"
    confidence = np.round(result[0]["score"], 3)
    return f"{label} (Confidence: {confidence})"

# Create Gradio interface for web-based text detection
gr.Interface(fn=predict_ai_text, inputs="text", outputs="text", title="AI Text Detector").launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://47b80a1564dcda77a8.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://47b80a1564dcda77a8.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Modify training parameters
training_args = TrainingArguments(
    output_dir="./ai_detector_tuned",  # New directory for tuned model checkpoints
    learning_rate=1e-5,  # Smaller learning rate
    weight_decay=0.01,
    per_device_train_batch_size=4,  # Slightly larger batch size
    per_device_eval_batch_size=4,
    num_train_epochs=5,  # Increased number of epochs
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_strategy="epoch",
    logging_steps=1,
    logging_dir="./logs_tuned",  # New directory for tuned training logs
    load_best_model_at_end=True,
    report_to=["wandb"],
)

# Re-initialize Trainer with modified TrainingArguments
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    tokenizer=tokenizer # Use tokenizer argument instead of processing_class
)

# Start training the model with the new parameters
trainer.train()
# Out:
# /tmp/ipython-input-3740566476.py:19: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='55' max='55' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [55/55 02:52, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.250500</td>
#       <td>0.533405</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.602600</td>
#       <td>1.042262</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.518200</td>
#       <td>0.764505</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.411300</td>
#       <td>0.668166</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from transformers import EvalPrediction
import numpy as np

def compute_metrics(p: EvalPrediction):
    preds = p.predictions[0] if isinstance(p.predictions, tuple) else p.predictions
    preds = np.argmax(preds, axis=1)
    labels = p.label_ids

    precision = precision_score(labels, preds)
    recall = recall_score(labels, preds)
    f1 = f1_score(labels, preds)
    accuracy = accuracy_score(labels, preds)

    return {"precision": precision, "recall": recall, "f1": f1, "accuracy": accuracy}

# Re-initialize Trainer with compute_metrics
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["test"],
    tokenizer=tokenizer,
    compute_metrics=compute_metrics # Pass the compute_metrics function here
)

# Evaluate the trained model on the test dataset
eval_results = trainer.evaluate()

# Print the evaluation results
print("Evaluation Results:")
print(eval_results)
# Out:
# /tmp/ipython-input-3942431425.py:18: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='2' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2/2 00:00]
#     </div>
# Evaluation Results:
# {'eval_loss': 0.5334050059318542, 'eval_model_preparation_time': 0.0024, 'eval_precision': 1.0, 'eval_recall': 0.5, 'eval_f1': 0.6666666666666666, 'eval_accuracy': 0.8333333333333334, 'eval_runtime': 0.1119, 'eval_samples_per_second': 53.598, 'eval_steps_per_second': 17.866}

# %%
# Get predictions on the test set
predictions = trainer.predict(tokenized_datasets["test"])

# Extract predicted labels
predicted_labels = np.argmax(predictions.predictions, axis=1)

# Get true labels
true_labels = predictions.label_ids

# Iterate through the test dataset and identify misclassifications
print("Misclassified Examples:")
for i in range(len(tokenized_datasets["test"])):
    if predicted_labels[i] != true_labels[i]:
        print(f"Text: {tokenized_datasets['test'][i]['text']}")
        print(f"True Label: {'AI-Generated' if true_labels[i] == 1 else 'Human-Written'}")
        print(f"Predicted Label: {'AI-Generated' if predicted_labels[i] == 1 else 'Human-Written'}")
        print("-" * 20)
# Out:
# Misclassified Examples:

# %%
import torch

# Ensure the model is on the correct device (CPU)
model_new.eval()
model_new.to('cpu')

predicted_labels_new = []
true_labels_new = []

print("Misclassified Examples (DistilBERT):")

# Iterate through the test dataset
for i in range(len(tokenized_datasets["test"])):
    # Get the input text and true label
    text = tokenized_datasets["test"][i]["text"]
    true_label = tokenized_datasets["test"][i]["label"]
    true_labels_new.append(true_label)

    # Tokenize the text and move to the same device as the model
    inputs = tokenizer_new(text, return_tensors="pt", padding="max_length", truncation=True, max_length=128).to('cpu')

    # Perform prediction manually
    with torch.no_grad():
        outputs = model_new(**inputs)
        logits = outputs.logits
        predicted_label = torch.argmax(logits, axis=1).item()
        predicted_labels_new.append(predicted_label)

    # Check for misclassification and print details
    if predicted_label != true_label:
        print(f"Text: {text}")
        print(f"True Label: {'AI-Generated' if true_label == 1 else 'Human-Written'}")
        print(f"Predicted Label: {'AI-Generated' if predicted_label == 1 else 'Human-Written'}")
        print("-" * 20)
# Out:
# Misclassified Examples (DistilBERT):
# Text: Learning a new language opens up opportunities to connect with people from different cultures.
# True Label: Human-Written
# Predicted Label: AI-Generated
# --------------------
# Text: Sometimes, the hardest goodbyes are the ones you never get to say.
# True Label: Human-Written
# Predicted Label: AI-Generated
# --------------------
